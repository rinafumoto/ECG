# %%
import numpy as np

import pandas as pd

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras import optimizers
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.utils import to_categorical

from sklearn.utils import resample

from warnings import filterwarnings
filterwarnings('ignore')

train_df = pd.read_csv('../data/mitbih_train.csv', header=None)
test_df = pd.read_csv('../data/mitbih_test.csv', header=None)
weight_path = "weights_mlp.hdf5"

df_1 = train_df[train_df[187] == 1]
df_2 = train_df[train_df[187] == 2]
df_3 = train_df[train_df[187] == 3]
df_4 = train_df[train_df[187] == 4]
df_0 = (train_df[train_df[187] == 0]).sample(n=20000, random_state=42)

df_1_upsample = resample(df_1, replace=True, n_samples=20000, random_state=123)
df_2_upsample = resample(df_2, replace=True, n_samples=20000, random_state=124)
df_3_upsample = resample(df_3, replace=True, n_samples=20000, random_state=125)
df_4_upsample = resample(df_4, replace=True, n_samples=20000, random_state=126)

train_df = pd.concat([df_0, df_1_upsample, df_2_upsample, df_3_upsample, df_4_upsample])

y_train = to_categorical(train_df[187], 5)
y_test = to_categorical(test_df[187], 5)

x_train = train_df.iloc[:, :187].values
x_test = test_df.iloc[:, :187].values
x_train = x_train.reshape(len(x_train), x_train.shape[1])
x_test = x_test.reshape(len(x_test), x_test.shape[1])

train_weights = True
batch_size = 100
epochs = 100

model = Sequential()
model.add(Dense(5, input_shape=(187, )))
model.add(Dense(64, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(64, activation='relu'))
model.add(Dense(5, activation='softmax'))
adam = optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
model.compile(loss='categorical_crossentropy', optimizer=adam, metrics=['accuracy'])
model.summary()

checkpoint = ModelCheckpoint(weight_path, monitor='loss', verbose=1, save_best_only=True, mode='min')

if train_weights:
    model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              callbacks=[checkpoint])

else:
    model.load_weights(weight_path)
    model.compile(loss='categorical_crossentropy', optimizer=adam, metrics=['accuracy'])

score, acc = model.evaluate(x_test, y_test, batch_size=batch_size)
print(score, acc)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 5)                 940
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                384
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               8320
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_6 (Dense)              (None, 5)                 325
# =================================================================
# Total params: 51,249
# Trainable params: 51,249
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
#  995/1000 [============================>.] - ETA: 0s - loss: 0.6163 - accuracy: 0.7637
# Epoch 00001: loss improved from inf to 0.61552, saving model to weights_mlp.hdf5
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.6155 - accuracy: 0.7641 - val_loss: 0.6303 - val_accuracy: 0.8061
# Epoch 2/100
#  987/1000 [============================>.] - ETA: 0s - loss: 0.4106 - accuracy: 0.8422
# Epoch 00002: loss improved from 0.61552 to 0.41037, saving model to weights_mlp.hdf5
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.4104 - accuracy: 0.8424 - val_loss: 0.6340 - val_accuracy: 0.7331
# Epoch 3/100
#  993/1000 [============================>.] - ETA: 0s - loss: 0.3412 - accuracy: 0.8696
# Epoch 00003: loss improved from 0.41037 to 0.34102, saving model to weights_mlp.hdf5
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.3410 - accuracy: 0.8698 - val_loss: 0.4954 - val_accuracy: 0.8064
# Epoch 4/100
#  994/1000 [============================>.] - ETA: 0s - loss: 0.2962 - accuracy: 0.8872
# Epoch 00004: loss improved from 0.34102 to 0.29603, saving model to weights_mlp.hdf5
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.2960 - accuracy: 0.8873 - val_loss: 0.5297 - val_accuracy: 0.7770
# Epoch 5/100
#  985/1000 [============================>.] - ETA: 0s - loss: 0.2660 - accuracy: 0.8997
# Epoch 00005: loss improved from 0.29603 to 0.26586, saving model to weights_mlp.hdf5
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.2659 - accuracy: 0.8999 - val_loss: 0.3577 - val_accuracy: 0.8618
# Epoch 6/100
#  988/1000 [============================>.] - ETA: 0s - loss: 0.2390 - accuracy: 0.9112
# Epoch 00006: loss improved from 0.26586 to 0.23857, saving model to weights_mlp.hdf5
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.2386 - accuracy: 0.9113 - val_loss: 0.4181 - val_accuracy: 0.8305
# Epoch 7/100
#  987/1000 [============================>.] - ETA: 0s - loss: 0.2241 - accuracy: 0.9167
# Epoch 00007: loss improved from 0.23857 to 0.22424, saving model to weights_mlp.hdf5
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.2242 - accuracy: 0.9168 - val_loss: 0.4252 - val_accuracy: 0.8179
# Epoch 8/100
#  999/1000 [============================>.] - ETA: 0s - loss: 0.2078 - accuracy: 0.9234
# Epoch 00008: loss improved from 0.22424 to 0.20774, saving model to weights_mlp.hdf5
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.2077 - accuracy: 0.9234 - val_loss: 0.3958 - val_accuracy: 0.8367
# Epoch 9/100
#  993/1000 [============================>.] - ETA: 0s - loss: 0.1934 - accuracy: 0.9287
# Epoch 00009: loss improved from 0.20774 to 0.19318, saving model to weights_mlp.hdf5
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.1932 - accuracy: 0.9288 - val_loss: 0.4243 - val_accuracy: 0.8355
# Epoch 10/100
#  983/1000 [============================>.] - ETA: 0s - loss: 0.1824 - accuracy: 0.9325
# Epoch 00010: loss improved from 0.19318 to 0.18261, saving model to weights_mlp.hdf5
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.1826 - accuracy: 0.9324 - val_loss: 0.3355 - val_accuracy: 0.8719
# Epoch 11/100
#  988/1000 [============================>.] - ETA: 0s - loss: 0.1734 - accuracy: 0.9362
# Epoch 00011: loss improved from 0.18261 to 0.17331, saving model to weights_mlp.hdf5
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.1733 - accuracy: 0.9362 - val_loss: 0.3322 - val_accuracy: 0.8744
# Epoch 12/100
#  982/1000 [============================>.] - ETA: 0s - loss: 0.1640 - accuracy: 0.9398
# Epoch 00012: loss improved from 0.17331 to 0.16431, saving model to weights_mlp.hdf5
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.1643 - accuracy: 0.9397 - val_loss: 0.3678 - val_accuracy: 0.8587
# Epoch 13/100
#  992/1000 [============================>.] - ETA: 0s - loss: 0.1586 - accuracy: 0.9423
# Epoch 00013: loss improved from 0.16431 to 0.15876, saving model to weights_mlp.hdf5
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.1588 - accuracy: 0.9422 - val_loss: 0.3392 - val_accuracy: 0.8707
# Epoch 14/100
# 1000/1000 [==============================] - ETA: 0s - loss: 0.1522 - accuracy: 0.9442
# Epoch 00014: loss improved from 0.15876 to 0.15218, saving model to weights_mlp.hdf5
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.1522 - accuracy: 0.9442 - val_loss: 0.3176 - val_accuracy: 0.8857
# Epoch 15/100
#  985/1000 [============================>.] - ETA: 0s - loss: 0.1456 - accuracy: 0.9468
# Epoch 00015: loss improved from 0.15218 to 0.14544, saving model to weights_mlp.hdf5
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.1454 - accuracy: 0.9468 - val_loss: 0.3540 - val_accuracy: 0.8747
# Epoch 16/100
#  997/1000 [============================>.] - ETA: 0s - loss: 0.1414 - accuracy: 0.9482
# Epoch 00016: loss improved from 0.14544 to 0.14142, saving model to weights_mlp.hdf5
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.1414 - accuracy: 0.9482 - val_loss: 0.3126 - val_accuracy: 0.8863
# Epoch 17/100
#  987/1000 [============================>.] - ETA: 0s - loss: 0.1357 - accuracy: 0.9512
# Epoch 00017: loss improved from 0.14142 to 0.13574, saving model to weights_mlp.hdf5
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.1357 - accuracy: 0.9512 - val_loss: 0.3574 - val_accuracy: 0.8699
# Epoch 18/100
#  979/1000 [============================>.] - ETA: 0s - loss: 0.1308 - accuracy: 0.9530
# Epoch 00018: loss improved from 0.13574 to 0.13123, saving model to weights_mlp.hdf5
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.1312 - accuracy: 0.9528 - val_loss: 0.3219 - val_accuracy: 0.8874
# Epoch 19/100
#  998/1000 [============================>.] - ETA: 0s - loss: 0.1288 - accuracy: 0.9537
# Epoch 00019: loss improved from 0.13123 to 0.12880, saving model to weights_mlp.hdf5
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.1288 - accuracy: 0.9537 - val_loss: 0.2854 - val_accuracy: 0.9104
# Epoch 20/100
#  992/1000 [============================>.] - ETA: 0s - loss: 0.1254 - accuracy: 0.9549 ETA: 0s - loss: 0.1257 - accuracy: 0.
# Epoch 00020: loss improved from 0.12880 to 0.12524, saving model to weights_mlp.hdf5
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.1252 - accuracy: 0.9550 - val_loss: 0.3344 - val_accuracy: 0.8900
# Epoch 21/100
#  997/1000 [============================>.] - ETA: 0s - loss: 0.1212 - accuracy: 0.9569
# Epoch 00021: loss improved from 0.12524 to 0.12134, saving model to weights_mlp.hdf5
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.1213 - accuracy: 0.9568 - val_loss: 0.3142 - val_accuracy: 0.8941
# Epoch 22/100
#  987/1000 [============================>.] - ETA: 0s - loss: 0.1162 - accuracy: 0.9581
# Epoch 00022: loss improved from 0.12134 to 0.11642, saving model to weights_mlp.hdf5
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.1164 - accuracy: 0.9580 - val_loss: 0.3198 - val_accuracy: 0.8958
# Epoch 23/100
#  982/1000 [============================>.] - ETA: 0s - loss: 0.1133 - accuracy: 0.9595
# Epoch 00023: loss improved from 0.11642 to 0.11367, saving model to weights_mlp.hdf5
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.1137 - accuracy: 0.9593 - val_loss: 0.3610 - val_accuracy: 0.8767
# Epoch 24/100
#  976/1000 [============================>.] - ETA: 0s - loss: 0.1153 - accuracy: 0.9597
# Epoch 00024: loss did not improve from 0.11367
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.1151 - accuracy: 0.9598 - val_loss: 0.3364 - val_accuracy: 0.8943
# Epoch 25/100
#  997/1000 [============================>.] - ETA: 0s - loss: 0.1127 - accuracy: 0.9598
# Epoch 00025: loss improved from 0.11367 to 0.11277, saving model to weights_mlp.hdf5
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.1128 - accuracy: 0.9597 - val_loss: 0.3240 - val_accuracy: 0.8911
# Epoch 26/100
#  999/1000 [============================>.] - ETA: 0s - loss: 0.1070 - accuracy: 0.9622
# Epoch 00026: loss improved from 0.11277 to 0.10695, saving model to weights_mlp.hdf5
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.1069 - accuracy: 0.9621 - val_loss: 0.3576 - val_accuracy: 0.8774
# Epoch 27/100
#  999/1000 [============================>.] - ETA: 0s - loss: 0.1074 - accuracy: 0.9623
# Epoch 00027: loss did not improve from 0.10695
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.1074 - accuracy: 0.9623 - val_loss: 0.3475 - val_accuracy: 0.8859
# Epoch 28/100
#  986/1000 [============================>.] - ETA: 0s - loss: 0.1010 - accuracy: 0.9640
# Epoch 00028: loss improved from 0.10695 to 0.10105, saving model to weights_mlp.hdf5
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.1011 - accuracy: 0.9640 - val_loss: 0.3370 - val_accuracy: 0.8952
# Epoch 29/100
#  981/1000 [============================>.] - ETA: 0s - loss: 0.1042 - accuracy: 0.9628
# Epoch 00029: loss did not improve from 0.10105
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.1047 - accuracy: 0.9627 - val_loss: 0.3220 - val_accuracy: 0.8971
# Epoch 30/100
#  990/1000 [============================>.] - ETA: 0s - loss: 0.1006 - accuracy: 0.9640
# Epoch 00030: loss improved from 0.10105 to 0.10059, saving model to weights_mlp.hdf5
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.1006 - accuracy: 0.9640 - val_loss: 0.2983 - val_accuracy: 0.9127
# Epoch 31/100
# 1000/1000 [==============================] - ETA: 0s - loss: 0.1000 - accuracy: 0.9646
# Epoch 00031: loss improved from 0.10059 to 0.09998, saving model to weights_mlp.hdf5
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.1000 - accuracy: 0.9646 - val_loss: 0.3409 - val_accuracy: 0.8925
# Epoch 32/100
#  981/1000 [============================>.] - ETA: 0s - loss: 0.0967 - accuracy: 0.9662
# Epoch 00032: loss improved from 0.09998 to 0.09693, saving model to weights_mlp.hdf5
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0969 - accuracy: 0.9661 - val_loss: 0.3876 - val_accuracy: 0.8734
# Epoch 33/100
#  983/1000 [============================>.] - ETA: 0s - loss: 0.0953 - accuracy: 0.9662
# Epoch 00033: loss improved from 0.09693 to 0.09554, saving model to weights_mlp.hdf5
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0955 - accuracy: 0.9661 - val_loss: 0.3425 - val_accuracy: 0.8973
# Epoch 34/100
#  981/1000 [============================>.] - ETA: 0s - loss: 0.0947 - accuracy: 0.9669
# Epoch 00034: loss improved from 0.09554 to 0.09451, saving model to weights_mlp.hdf5
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0945 - accuracy: 0.9668 - val_loss: 0.3174 - val_accuracy: 0.9123
# Epoch 35/100
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0927 - accuracy: 0.9678
# Epoch 00035: loss improved from 0.09451 to 0.09273, saving model to weights_mlp.hdf5
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0927 - accuracy: 0.9678 - val_loss: 0.3820 - val_accuracy: 0.8799
# Epoch 36/100
#  996/1000 [============================>.] - ETA: 0s - loss: 0.0897 - accuracy: 0.9683
# Epoch 00036: loss improved from 0.09273 to 0.08986, saving model to weights_mlp.hdf5
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.0899 - accuracy: 0.9683 - val_loss: 0.3161 - val_accuracy: 0.9133
# Epoch 37/100
#  987/1000 [============================>.] - ETA: 0s - loss: 0.0909 - accuracy: 0.9681
# Epoch 00037: loss did not improve from 0.08986
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0907 - accuracy: 0.9682 - val_loss: 0.3319 - val_accuracy: 0.9082
# Epoch 38/100
#  986/1000 [============================>.] - ETA: 0s - loss: 0.0883 - accuracy: 0.9690
# Epoch 00038: loss improved from 0.08986 to 0.08822, saving model to weights_mlp.hdf5
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0882 - accuracy: 0.9690 - val_loss: 0.3353 - val_accuracy: 0.9067
# Epoch 39/100
#  995/1000 [============================>.] - ETA: 0s - loss: 0.0850 - accuracy: 0.9695
# Epoch 00039: loss improved from 0.08822 to 0.08504, saving model to weights_mlp.hdf5
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0850 - accuracy: 0.9695 - val_loss: 0.3698 - val_accuracy: 0.8966
# Epoch 40/100
#  992/1000 [============================>.] - ETA: 0s - loss: 0.0848 - accuracy: 0.9701
# Epoch 00040: loss improved from 0.08504 to 0.08485, saving model to weights_mlp.hdf5
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.0849 - accuracy: 0.9701 - val_loss: 0.3720 - val_accuracy: 0.8942
# Epoch 41/100
#  981/1000 [============================>.] - ETA: 0s - loss: 0.0860 - accuracy: 0.9691
# Epoch 00041: loss did not improve from 0.08485
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.0859 - accuracy: 0.9692 - val_loss: 0.3610 - val_accuracy: 0.9001
# Epoch 42/100
#  996/1000 [============================>.] - ETA: 0s - loss: 0.0817 - accuracy: 0.9712
# Epoch 00042: loss improved from 0.08485 to 0.08171, saving model to weights_mlp.hdf5
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.0817 - accuracy: 0.9712 - val_loss: 0.3444 - val_accuracy: 0.9073
# Epoch 43/100
#  997/1000 [============================>.] - ETA: 0s - loss: 0.0822 - accuracy: 0.9711
# Epoch 00043: loss did not improve from 0.08171
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.0824 - accuracy: 0.9710 - val_loss: 0.3479 - val_accuracy: 0.8998
# Epoch 44/100
#  988/1000 [============================>.] - ETA: 0s - loss: 0.0797 - accuracy: 0.9720
# Epoch 00044: loss improved from 0.08171 to 0.07994, saving model to weights_mlp.hdf5
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0799 - accuracy: 0.9719 - val_loss: 0.3350 - val_accuracy: 0.9121
# Epoch 45/100
#  997/1000 [============================>.] - ETA: 0s - loss: 0.0821 - accuracy: 0.9711
# Epoch 00045: loss did not improve from 0.07994
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0820 - accuracy: 0.9711 - val_loss: 0.3552 - val_accuracy: 0.9055
# Epoch 46/100
#  988/1000 [============================>.] - ETA: 0s - loss: 0.0776 - accuracy: 0.9730
# Epoch 00046: loss improved from 0.07994 to 0.07761, saving model to weights_mlp.hdf5
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.0776 - accuracy: 0.9730 - val_loss: 0.3579 - val_accuracy: 0.9037
# Epoch 47/100
#  993/1000 [============================>.] - ETA: 0s - loss: 0.0800 - accuracy: 0.9716
# Epoch 00047: loss did not improve from 0.07761
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.0798 - accuracy: 0.9717 - val_loss: 0.3472 - val_accuracy: 0.9128
# Epoch 48/100
#  982/1000 [============================>.] - ETA: 0s - loss: 0.0757 - accuracy: 0.9734
# Epoch 00048: loss improved from 0.07761 to 0.07532, saving model to weights_mlp.hdf5
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.0753 - accuracy: 0.9736 - val_loss: 0.3904 - val_accuracy: 0.9027
# Epoch 49/100
#  999/1000 [============================>.] - ETA: 0s - loss: 0.0735 - accuracy: 0.9745
# Epoch 00049: loss improved from 0.07532 to 0.07354, saving model to weights_mlp.hdf5
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.0735 - accuracy: 0.9745 - val_loss: 0.3389 - val_accuracy: 0.9154
# Epoch 50/100
#  999/1000 [============================>.] - ETA: 0s - loss: 0.0762 - accuracy: 0.9736
# Epoch 00050: loss did not improve from 0.07354
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0761 - accuracy: 0.9736 - val_loss: 0.3654 - val_accuracy: 0.9043
# Epoch 51/100
#  977/1000 [============================>.] - ETA: 0s - loss: 0.0757 - accuracy: 0.9740
# Epoch 00051: loss did not improve from 0.07354
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0752 - accuracy: 0.9741 - val_loss: 0.3687 - val_accuracy: 0.9076
# Epoch 52/100
#  991/1000 [============================>.] - ETA: 0s - loss: 0.0742 - accuracy: 0.9739
# Epoch 00052: loss did not improve from 0.07354
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0739 - accuracy: 0.9739 - val_loss: 0.3550 - val_accuracy: 0.9148
# Epoch 53/100
#  984/1000 [============================>.] - ETA: 0s - loss: 0.0716 - accuracy: 0.9753
# Epoch 00053: loss improved from 0.07354 to 0.07152, saving model to weights_mlp.hdf5
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.0715 - accuracy: 0.9753 - val_loss: 0.3546 - val_accuracy: 0.9143
# Epoch 54/100
#  993/1000 [============================>.] - ETA: 0s - loss: 0.0702 - accuracy: 0.9754
# Epoch 00054: loss improved from 0.07152 to 0.07016, saving model to weights_mlp.hdf5
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.0702 - accuracy: 0.9754 - val_loss: 0.3529 - val_accuracy: 0.9132
# Epoch 55/100
#  990/1000 [============================>.] - ETA: 0s - loss: 0.0710 - accuracy: 0.9751
# Epoch 00055: loss did not improve from 0.07016
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.0711 - accuracy: 0.9751 - val_loss: 0.3394 - val_accuracy: 0.9113
# Epoch 56/100
#  990/1000 [============================>.] - ETA: 0s - loss: 0.0682 - accuracy: 0.9768
# Epoch 00056: loss improved from 0.07016 to 0.06832, saving model to weights_mlp.hdf5
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.0683 - accuracy: 0.9768 - val_loss: 0.3671 - val_accuracy: 0.9046
# Epoch 57/100
#  985/1000 [============================>.] - ETA: 0s - loss: 0.0692 - accuracy: 0.9754
# Epoch 00057: loss did not improve from 0.06832
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.0695 - accuracy: 0.9753 - val_loss: 0.3211 - val_accuracy: 0.9172
# Epoch 58/100
#  981/1000 [============================>.] - ETA: 0s - loss: 0.0678 - accuracy: 0.9763
# Epoch 00058: loss improved from 0.06832 to 0.06746, saving model to weights_mlp.hdf5
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.0675 - accuracy: 0.9764 - val_loss: 0.3430 - val_accuracy: 0.9207
# Epoch 59/100
#  984/1000 [============================>.] - ETA: 0s - loss: 0.0664 - accuracy: 0.9767
# Epoch 00059: loss improved from 0.06746 to 0.06671, saving model to weights_mlp.hdf5
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.0667 - accuracy: 0.9765 - val_loss: 0.3771 - val_accuracy: 0.9065
# Epoch 60/100
#  982/1000 [============================>.] - ETA: 0s - loss: 0.0686 - accuracy: 0.9762
# Epoch 00060: loss did not improve from 0.06671
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.0686 - accuracy: 0.9762 - val_loss: 0.3558 - val_accuracy: 0.9174
# Epoch 61/100
#  997/1000 [============================>.] - ETA: 0s - loss: 0.0656 - accuracy: 0.9773
# Epoch 00061: loss improved from 0.06671 to 0.06550, saving model to weights_mlp.hdf5
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.0655 - accuracy: 0.9773 - val_loss: 0.3541 - val_accuracy: 0.9147
# Epoch 62/100
#  992/1000 [============================>.] - ETA: 0s - loss: 0.0615 - accuracy: 0.9784
# Epoch 00062: loss improved from 0.06550 to 0.06172, saving model to weights_mlp.hdf5
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.0617 - accuracy: 0.9783 - val_loss: 0.3288 - val_accuracy: 0.9207
# Epoch 63/100
#  993/1000 [============================>.] - ETA: 0s - loss: 0.0674 - accuracy: 0.9768
# Epoch 00063: loss did not improve from 0.06172
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0674 - accuracy: 0.9768 - val_loss: 0.3864 - val_accuracy: 0.9063
# Epoch 64/100
#  996/1000 [============================>.] - ETA: 0s - loss: 0.0643 - accuracy: 0.9775
# Epoch 00064: loss did not improve from 0.06172
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0643 - accuracy: 0.9775 - val_loss: 0.3792 - val_accuracy: 0.9067
# Epoch 65/100
#  996/1000 [============================>.] - ETA: 0s - loss: 0.0631 - accuracy: 0.9782
# Epoch 00065: loss did not improve from 0.06172
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.0632 - accuracy: 0.9782 - val_loss: 0.3524 - val_accuracy: 0.9194
# Epoch 66/100
#  982/1000 [============================>.] - ETA: 0s - loss: 0.0661 - accuracy: 0.9775
# Epoch 00066: loss did not improve from 0.06172
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.0661 - accuracy: 0.9775 - val_loss: 0.4005 - val_accuracy: 0.8950
# Epoch 67/100
#  997/1000 [============================>.] - ETA: 0s - loss: 0.0626 - accuracy: 0.9785
# Epoch 00067: loss did not improve from 0.06172
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.0626 - accuracy: 0.9785 - val_loss: 0.3943 - val_accuracy: 0.9123
# Epoch 68/100
#  997/1000 [============================>.] - ETA: 0s - loss: 0.0639 - accuracy: 0.9777
# Epoch 00068: loss did not improve from 0.06172
# 1000/1000 [==============================] - 4s 4ms/step - loss: 0.0638 - accuracy: 0.9777 - val_loss: 0.3744 - val_accuracy: 0.9112
# Epoch 69/100
#  997/1000 [============================>.] - ETA: 0s - loss: 0.0596 - accuracy: 0.9791
# Epoch 00069: loss improved from 0.06172 to 0.05963, saving model to weights_mlp.hdf5
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.0596 - accuracy: 0.9791 - val_loss: 0.3661 - val_accuracy: 0.9218
# Epoch 70/100
#  991/1000 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.9790
# Epoch 00070: loss did not improve from 0.05963
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.0611 - accuracy: 0.9789 - val_loss: 0.3538 - val_accuracy: 0.9157
# Epoch 71/100
#  995/1000 [============================>.] - ETA: 0s - loss: 0.0608 - accuracy: 0.9789
# Epoch 00071: loss did not improve from 0.05963
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.0609 - accuracy: 0.9788 - val_loss: 0.3758 - val_accuracy: 0.9143
# Epoch 72/100
#  995/1000 [============================>.] - ETA: 0s - loss: 0.0593 - accuracy: 0.9798
# Epoch 00072: loss improved from 0.05963 to 0.05929, saving model to weights_mlp.hdf5
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.0593 - accuracy: 0.9798 - val_loss: 0.3439 - val_accuracy: 0.9225
# Epoch 73/100
#  983/1000 [============================>.] - ETA: 0s - loss: 0.0572 - accuracy: 0.9803
# Epoch 00073: loss improved from 0.05929 to 0.05701, saving model to weights_mlp.hdf5
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.0570 - accuracy: 0.9803 - val_loss: 0.3720 - val_accuracy: 0.9178
# Epoch 74/100
#  986/1000 [============================>.] - ETA: 0s - loss: 0.0579 - accuracy: 0.9800
# Epoch 00074: loss did not improve from 0.05701
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.0580 - accuracy: 0.9799 - val_loss: 0.4142 - val_accuracy: 0.9029
# Epoch 75/100
#  996/1000 [============================>.] - ETA: 0s - loss: 0.0597 - accuracy: 0.9791
# Epoch 00075: loss did not improve from 0.05701
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.0598 - accuracy: 0.9791 - val_loss: 0.3710 - val_accuracy: 0.9144
# Epoch 76/100
#  982/1000 [============================>.] - ETA: 0s - loss: 0.0589 - accuracy: 0.9800
# Epoch 00076: loss did not improve from 0.05701
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.0588 - accuracy: 0.9800 - val_loss: 0.3777 - val_accuracy: 0.9203
# Epoch 77/100
#  995/1000 [============================>.] - ETA: 0s - loss: 0.0596 - accuracy: 0.9795
# Epoch 00077: loss did not improve from 0.05701
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.0597 - accuracy: 0.9796 - val_loss: 0.3334 - val_accuracy: 0.9207
# Epoch 78/100
#  989/1000 [============================>.] - ETA: 0s - loss: 0.0548 - accuracy: 0.9813
# Epoch 00078: loss improved from 0.05701 to 0.05501, saving model to weights_mlp.hdf5
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.0550 - accuracy: 0.9812 - val_loss: 0.3510 - val_accuracy: 0.9227
# Epoch 79/100
#  990/1000 [============================>.] - ETA: 0s - loss: 0.0555 - accuracy: 0.9807
# Epoch 00079: loss did not improve from 0.05501
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.0554 - accuracy: 0.9808 - val_loss: 0.3663 - val_accuracy: 0.9214
# Epoch 80/100
#  991/1000 [============================>.] - ETA: 0s - loss: 0.0569 - accuracy: 0.9805
# Epoch 00080: loss did not improve from 0.05501
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.0569 - accuracy: 0.9806 - val_loss: 0.3838 - val_accuracy: 0.9174
# Epoch 81/100
#  988/1000 [============================>.] - ETA: 0s - loss: 0.0534 - accuracy: 0.9817
# Epoch 00081: loss improved from 0.05501 to 0.05344, saving model to weights_mlp.hdf5
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.0534 - accuracy: 0.9817 - val_loss: 0.3775 - val_accuracy: 0.9200
# Epoch 82/100
#  991/1000 [============================>.] - ETA: 0s - loss: 0.0559 - accuracy: 0.9809
# Epoch 00082: loss did not improve from 0.05344
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.0561 - accuracy: 0.9809 - val_loss: 0.3476 - val_accuracy: 0.9172
# Epoch 83/100
#  980/1000 [============================>.] - ETA: 0s - loss: 0.0561 - accuracy: 0.9805
# Epoch 00083: loss did not improve from 0.05344
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.0559 - accuracy: 0.9807 - val_loss: 0.3435 - val_accuracy: 0.9228
# Epoch 84/100
#  986/1000 [============================>.] - ETA: 0s - loss: 0.0530 - accuracy: 0.9813
# Epoch 00084: loss improved from 0.05344 to 0.05278, saving model to weights_mlp.hdf5
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.0528 - accuracy: 0.9815 - val_loss: 0.3778 - val_accuracy: 0.9201
# Epoch 85/100
#  985/1000 [============================>.] - ETA: 0s - loss: 0.0535 - accuracy: 0.9812
# Epoch 00085: loss did not improve from 0.05278
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.0535 - accuracy: 0.9811 - val_loss: 0.3755 - val_accuracy: 0.9210
# Epoch 86/100
#  991/1000 [============================>.] - ETA: 0s - loss: 0.0529 - accuracy: 0.9819
# Epoch 00086: loss did not improve from 0.05278
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.0529 - accuracy: 0.9819 - val_loss: 0.3663 - val_accuracy: 0.9225
# Epoch 87/100
#  986/1000 [============================>.] - ETA: 0s - loss: 0.0531 - accuracy: 0.9817
# Epoch 00087: loss did not improve from 0.05278
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0532 - accuracy: 0.9816 - val_loss: 0.3731 - val_accuracy: 0.9252
# Epoch 88/100
#  997/1000 [============================>.] - ETA: 0s - loss: 0.0539 - accuracy: 0.9811
# Epoch 00088: loss did not improve from 0.05278
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0539 - accuracy: 0.9811 - val_loss: 0.3596 - val_accuracy: 0.9268
# Epoch 89/100
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0509 - accuracy: 0.9826
# Epoch 00089: loss improved from 0.05278 to 0.05088, saving model to weights_mlp.hdf5
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.0509 - accuracy: 0.9826 - val_loss: 0.3818 - val_accuracy: 0.9250
# Epoch 90/100
#  985/1000 [============================>.] - ETA: 0s - loss: 0.0503 - accuracy: 0.9830
# Epoch 00090: loss improved from 0.05088 to 0.05043, saving model to weights_mlp.hdf5
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.0504 - accuracy: 0.9830 - val_loss: 0.3920 - val_accuracy: 0.9204
# Epoch 91/100
#  996/1000 [============================>.] - ETA: 0s - loss: 0.0540 - accuracy: 0.9820
# Epoch 00091: loss did not improve from 0.05043
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.0539 - accuracy: 0.9820 - val_loss: 0.3864 - val_accuracy: 0.9243
# Epoch 92/100
#  990/1000 [============================>.] - ETA: 0s - loss: 0.0580 - accuracy: 0.9801
# Epoch 00092: loss did not improve from 0.05043
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.0577 - accuracy: 0.9802 - val_loss: 0.3811 - val_accuracy: 0.9161
# Epoch 93/100
#  995/1000 [============================>.] - ETA: 0s - loss: 0.0510 - accuracy: 0.9826
# Epoch 00093: loss did not improve from 0.05043
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.0510 - accuracy: 0.9826 - val_loss: 0.3918 - val_accuracy: 0.9123
# Epoch 94/100
#  998/1000 [============================>.] - ETA: 0s - loss: 0.0466 - accuracy: 0.9841
# Epoch 00094: loss improved from 0.05043 to 0.04653, saving model to weights_mlp.hdf5
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.0465 - accuracy: 0.9841 - val_loss: 0.4240 - val_accuracy: 0.9144
# Epoch 95/100
#  995/1000 [============================>.] - ETA: 0s - loss: 0.0509 - accuracy: 0.9826
# Epoch 00095: loss did not improve from 0.04653
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.0508 - accuracy: 0.9827 - val_loss: 0.3788 - val_accuracy: 0.9244
# Epoch 96/100
#  998/1000 [============================>.] - ETA: 0s - loss: 0.0515 - accuracy: 0.9823
# Epoch 00096: loss did not improve from 0.04653
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.0515 - accuracy: 0.9822 - val_loss: 0.3646 - val_accuracy: 0.9207
# Epoch 97/100
#  999/1000 [============================>.] - ETA: 0s - loss: 0.0494 - accuracy: 0.9831
# Epoch 00097: loss did not improve from 0.04653
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.0495 - accuracy: 0.9831 - val_loss: 0.3957 - val_accuracy: 0.9155
# Epoch 98/100
#  981/1000 [============================>.] - ETA: 0s - loss: 0.0497 - accuracy: 0.9837
# Epoch 00098: loss did not improve from 0.04653
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.0496 - accuracy: 0.9837 - val_loss: 0.4227 - val_accuracy: 0.9115
# Epoch 99/100
# 1000/1000 [==============================] - ETA: 0s - loss: 0.0457 - accuracy: 0.9844
# Epoch 00099: loss improved from 0.04653 to 0.04571, saving model to weights_mlp.hdf5
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.0457 - accuracy: 0.9844 - val_loss: 0.4151 - val_accuracy: 0.9190
# Epoch 100/100
#  992/1000 [============================>.] - ETA: 0s - loss: 0.0500 - accuracy: 0.9826
# Epoch 00100: loss did not improve from 0.04571
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.0499 - accuracy: 0.9826 - val_loss: 0.3914 - val_accuracy: 0.9221
# 219/219 [==============================] - 0s 1ms/step - loss: 0.3914 - accuracy: 0.9221
# 0.3913643956184387 0.9220719933509827
