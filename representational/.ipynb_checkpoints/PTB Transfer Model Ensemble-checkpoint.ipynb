# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dropout, Dense, Conv1D, MaxPooling1D, Flatten, LeakyReLU, Input, Average
from tensorflow import keras
import tensorflow as tf
import pickle
import seaborn as sn
import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import pandas as pd

# %%
TRAIN_SET = '../ptb_train_set.pickle'
TEST_SET = '../ptb_test_set.pickle'

with open(TEST_SET, 'rb') as file:
    test_set = pickle.load(file)
    x_test = test_set['x']
    y_test = test_set['y']

with open(TRAIN_SET, 'rb') as file:
    train_set = pickle.load(file)
    x_train = train_set['x']
    y_train = train_set['y']
    
x_train = tf.expand_dims(x_train, axis=2)
x_test = tf.expand_dims(x_test, axis=2)
x_train.shape
# Out:
# TensorShape([13097, 187, 1])

# %%
CNN  = keras.models.load_model('CNN_REP_PTB')
LSTM = keras.models.load_model('LSTM_REP_PTB')
MLP  = keras.models.load_model('MLP_REP_PTB')

# %%
inputs = Input(shape=x_train.shape[1:])
cnn = CNN(inputs)
lstm = LSTM(inputs)
mlp = MLP(inputs)

y = Average()([cnn, lstm, mlp])


model = Model(inputs = inputs, outputs = y)

# %%
opt = keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
model.compile(loss='binary_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train,
              batch_size=64,
              epochs=20,
              validation_data=(x_test, y_test),
              shuffle=True)
# Out:
# Epoch 1/20
# 205/205 [==============================] - 25s 106ms/step - loss: 0.0883 - accuracy: 0.9802 - val_loss: 0.0948 - val_accuracy: 0.9759
# Epoch 2/20
# 205/205 [==============================] - 24s 116ms/step - loss: 0.0863 - accuracy: 0.9774 - val_loss: 0.0860 - val_accuracy: 0.9698
# Epoch 3/20
# 205/205 [==============================] - 23s 114ms/step - loss: 0.0805 - accuracy: 0.9749 - val_loss: 0.0824 - val_accuracy: 0.9732
# Epoch 4/20
# 205/205 [==============================] - 24s 118ms/step - loss: 0.0766 - accuracy: 0.9769 - val_loss: 0.0766 - val_accuracy: 0.9766
# Epoch 5/20
# 205/205 [==============================] - 21s 102ms/step - loss: 0.0784 - accuracy: 0.9813 - val_loss: 0.0782 - val_accuracy: 0.9780
# Epoch 6/20
# 205/205 [==============================] - 23s 111ms/step - loss: 0.0666 - accuracy: 0.9809 - val_loss: 0.0797 - val_accuracy: 0.9814
# Epoch 7/20
# 205/205 [==============================] - 22s 109ms/step - loss: 0.0719 - accuracy: 0.9794 - val_loss: 0.0835 - val_accuracy: 0.9732
# Epoch 8/20
# 205/205 [==============================] - 21s 105ms/step - loss: 0.0701 - accuracy: 0.9805 - val_loss: 0.0820 - val_accuracy: 0.9766
# Epoch 9/20
# 205/205 [==============================] - 22s 109ms/step - loss: 0.0701 - accuracy: 0.9816 - val_loss: 0.0866 - val_accuracy: 0.9849
# Epoch 10/20
# 205/205 [==============================] - 24s 117ms/step - loss: 0.0630 - accuracy: 0.9847 - val_loss: 0.1560 - val_accuracy: 0.9340
# Epoch 11/20
# 205/205 [==============================] - 22s 109ms/step - loss: 0.1026 - accuracy: 0.9672 - val_loss: 0.1051 - val_accuracy: 0.9595
# Epoch 12/20
# 205/205 [==============================] - 22s 107ms/step - loss: 0.0771 - accuracy: 0.9768 - val_loss: 0.0884 - val_accuracy: 0.9773
# Epoch 13/20
# 205/205 [==============================] - 22s 109ms/step - loss: 0.0647 - accuracy: 0.9830 - val_loss: 0.0876 - val_accuracy: 0.9780
# Epoch 14/20
# 205/205 [==============================] - 22s 107ms/step - loss: 0.0592 - accuracy: 0.9850 - val_loss: 0.0906 - val_accuracy: 0.9746
# Epoch 15/20
# 205/205 [==============================] - 22s 107ms/step - loss: 0.0640 - accuracy: 0.9833 - val_loss: 0.0867 - val_accuracy: 0.9746
# Epoch 16/20
# 205/205 [==============================] - 23s 110ms/step - loss: 0.0665 - accuracy: 0.9783 - val_loss: 0.1188 - val_accuracy: 0.9608
# Epoch 17/20
# 205/205 [==============================] - 23s 114ms/step - loss: 0.0840 - accuracy: 0.9749 - val_loss: 0.0998 - val_accuracy: 0.9711
# Epoch 18/20
# 205/205 [==============================] - 24s 116ms/step - loss: 0.0608 - accuracy: 0.9850 - val_loss: 0.0870 - val_accuracy: 0.9794
# Epoch 19/20
# 205/205 [==============================] - 24s 115ms/step - loss: 0.0586 - accuracy: 0.9853 - val_loss: 0.1145 - val_accuracy: 0.9718
# Epoch 20/20
# 205/205 [==============================] - 23s 115ms/step - loss: 0.0665 - accuracy: 0.9808 - val_loss: 0.0977 - val_accuracy: 0.9746

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sn
def plot_history(history):
    fig1, ax_acc = plt.subplots()
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.title('Model Accuracy')
    plt.legend(['Training', 'Validation'], loc='lower right')
    plt.show()
    fig2, ax_loss = plt.subplots()
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Model Loss')
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.legend(['Training', 'Validation'], loc='upper right')
    plt.show()
    
def plot_confusion(model, name):
    predictions = model.predict(x_test)
    matrix = confusion_matrix(y_test, np.round(predictions))
    df_cm = pd.DataFrame(matrix, range(2), range(2))
    plt.figure(figsize=(10,7))
    sn.set(font_scale=1.4) 
    labels = ["Normal", "Abnormal"]
    sn.heatmap(df_cm, annot=True, annot_kws={"size": 10}, xticklabels=labels, yticklabels=labels)
    plt.xlabel("Actual")
    plt.ylabel("Predicted")
    plt.title(name)
    plt.show()

# %%
plot_history(history)
plot_confusion(model, "PTB Final Ensemble")
