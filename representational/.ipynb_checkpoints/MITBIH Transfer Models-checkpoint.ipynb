# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dropout, Dense, Conv1D, MaxPooling1D, Flatten, LeakyReLU, Input, Concatenate
from tensorflow import keras
import tensorflow as tf
import pickle
import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import pandas as pd

# %%
TRAIN_SET = '../mit_train_set.pickle'
TEST_SET = '../mit_test_set.pickle'

with open(TEST_SET, 'rb') as file:
    test_set = pickle.load(file)
    x_test = test_set['x']
    y_test = test_set['y']

with open(TRAIN_SET, 'rb') as file:
    train_set = pickle.load(file)
    x_train = train_set['x']
    y_train = train_set['y']
    
x_train_mlp = x_train
x_test_mlp = x_test

x_train = tf.expand_dims(x_train, axis=2)
x_test = tf.expand_dims(x_test, axis=2)

# %%
num_classes = 5
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %%
CNN_model  = keras.models.load_model('CNN_REP')
LSTM_model = keras.models.load_model('LSTM_REP')
MLP_model  = keras.models.load_model('MLP_REP')

# %%
CNN = Model(inputs=CNN_model.input, outputs=CNN_model.layers[-10].output)
LSTM = Model(inputs=LSTM_model.input, outputs=LSTM_model.layers[-10].output)
MLP = Model(inputs=MLP_model.input, outputs=MLP_model.layers[-10].output)

# %%
CNN.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 187, 1)]          0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 185, 5)            20
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 185, 5)            0
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 92, 5)             0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 89, 10)            210
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 89, 10)            0
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 44, 10)            0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 41, 20)            820
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 41, 20)            0
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 20, 20)            0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 400)               0
# _________________________________________________________________
# dense_23 (Dense)             (None, 30)                12030
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 30)                0
# _________________________________________________________________
# dense_24 (Dense)             (None, 20)                620
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 20)                0
# =================================================================
# Total params: 13,700
# Trainable params: 13,700
# Non-trainable params: 0
# _________________________________________________________________

# %%
inputs = Input(shape=x_train.shape[1:])
x = CNN(inputs)
y = Dense(5, activation="softmax")(x)
CNN_model = Model(inputs = inputs, outputs = y)

# %%
opt = keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
CNN_model.compile(loss='binary_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

# %%
CNN_history = CNN_model.fit(x_train, y_train,
              batch_size=64,
              epochs=20,
              validation_data=(x_test, y_test))
# Out:
# Epoch 1/20
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.2941 - accuracy: 0.7235 - val_loss: 0.1322 - val_accuracy: 0.8760
# Epoch 2/20
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.1010 - accuracy: 0.9061 - val_loss: 0.1158 - val_accuracy: 0.8945
# Epoch 3/20
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0774 - accuracy: 0.9307 - val_loss: 0.1108 - val_accuracy: 0.9068
# Epoch 4/20
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0650 - accuracy: 0.9446 - val_loss: 0.1053 - val_accuracy: 0.9129
# Epoch 5/20
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0578 - accuracy: 0.9518 - val_loss: 0.1161 - val_accuracy: 0.9109
# Epoch 6/20
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0508 - accuracy: 0.9593 - val_loss: 0.1026 - val_accuracy: 0.9208
# Epoch 7/20
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0475 - accuracy: 0.9615 - val_loss: 0.1121 - val_accuracy: 0.9192
# Epoch 8/20
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0424 - accuracy: 0.9678 - val_loss: 0.1074 - val_accuracy: 0.9267
# Epoch 9/20
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0390 - accuracy: 0.9699 - val_loss: 0.1095 - val_accuracy: 0.9219
# Epoch 10/20
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0362 - accuracy: 0.9720 - val_loss: 0.1115 - val_accuracy: 0.9232
# Epoch 11/20
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0344 - accuracy: 0.9739 - val_loss: 0.1242 - val_accuracy: 0.9200
# Epoch 12/20
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0315 - accuracy: 0.9771 - val_loss: 0.1225 - val_accuracy: 0.9293
# Epoch 13/20
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0299 - accuracy: 0.9785 - val_loss: 0.1280 - val_accuracy: 0.9246
# Epoch 14/20
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0282 - accuracy: 0.9799 - val_loss: 0.1336 - val_accuracy: 0.9184
# Epoch 15/20
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0269 - accuracy: 0.9809 - val_loss: 0.1204 - val_accuracy: 0.9288
# Epoch 16/20
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0247 - accuracy: 0.9829 - val_loss: 0.1495 - val_accuracy: 0.9201
# Epoch 17/20
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0235 - accuracy: 0.9831 - val_loss: 0.1492 - val_accuracy: 0.9225
# Epoch 18/20
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0226 - accuracy: 0.9840 - val_loss: 0.1399 - val_accuracy: 0.9293
# Epoch 19/20
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0218 - accuracy: 0.9851 - val_loss: 0.1533 - val_accuracy: 0.9204
# Epoch 20/20
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0208 - accuracy: 0.9850 - val_loss: 0.1489 - val_accuracy: 0.9217

# %%
inputs = Input(shape=x_train.shape[1:])
x = MLP(inputs)
y = Dense(5, activation="softmax")(x)
MLP_model = Model(inputs = inputs, outputs = y)

# %%
opt = keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
MLP_model.compile(loss='binary_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

# %%
MLP_history = MLP_model.fit(x_train_mlp, y_train,
              batch_size=64,
              epochs=20,
              validation_data=(x_test_mlp, y_test))
# Out:
# Epoch 1/20
# 1563/1563 [==============================] - 93s 59ms/step - loss: 0.1841 - accuracy: 0.8224 - val_loss: 0.1748 - val_accuracy: 0.8383
# Epoch 2/20
# 1563/1563 [==============================] - 90s 58ms/step - loss: 0.1368 - accuracy: 0.8767 - val_loss: 0.1568 - val_accuracy: 0.8554
# Epoch 3/20
# 1563/1563 [==============================] - 91s 58ms/step - loss: 0.1190 - accuracy: 0.8971 - val_loss: 0.1582 - val_accuracy: 0.8636
# Epoch 4/20
# 1563/1563 [==============================] - 98s 62ms/step - loss: 0.1079 - accuracy: 0.9093 - val_loss: 0.1792 - val_accuracy: 0.8561
# Epoch 5/20
# 1563/1563 [==============================] - 97s 62ms/step - loss: 0.1003 - accuracy: 0.9191 - val_loss: 0.1674 - val_accuracy: 0.8682
# Epoch 6/20
# 1563/1563 [==============================] - 96s 62ms/step - loss: 0.0935 - accuracy: 0.9266 - val_loss: 0.1669 - val_accuracy: 0.8709
# Epoch 7/20
# 1563/1563 [==============================] - 99s 63ms/step - loss: 0.0883 - accuracy: 0.9324 - val_loss: 0.1815 - val_accuracy: 0.8651
# Epoch 8/20
# 1563/1563 [==============================] - 94s 60ms/step - loss: 0.0840 - accuracy: 0.9370 - val_loss: 0.1871 - val_accuracy: 0.8676
# Epoch 9/20
# 1563/1563 [==============================] - 101s 64ms/step - loss: 0.0807 - accuracy: 0.9393 - val_loss: 0.1981 - val_accuracy: 0.8658
# Epoch 10/20
# 1563/1563 [==============================] - 95s 61ms/step - loss: 0.0774 - accuracy: 0.9433 - val_loss: 0.1979 - val_accuracy: 0.8677
# Epoch 11/20
# 1563/1563 [==============================] - 93s 60ms/step - loss: 0.0745 - accuracy: 0.9459 - val_loss: 0.2020 - val_accuracy: 0.8705
# Epoch 12/20
# 1563/1563 [==============================] - 109s 70ms/step - loss: 0.0717 - accuracy: 0.9495 - val_loss: 0.2042 - val_accuracy: 0.8701
# Epoch 13/20
# 1563/1563 [==============================] - 92s 59ms/step - loss: 0.0695 - accuracy: 0.9513 - val_loss: 0.2206 - val_accuracy: 0.8637
# Epoch 14/20
# 1563/1563 [==============================] - 92s 59ms/step - loss: 0.0666 - accuracy: 0.9549 - val_loss: 0.2365 - val_accuracy: 0.8657
# Epoch 15/20
# 1563/1563 [==============================] - 87s 55ms/step - loss: 0.0652 - accuracy: 0.9552 - val_loss: 0.2312 - val_accuracy: 0.8644
# Epoch 16/20
# 1563/1563 [==============================] - 84s 54ms/step - loss: 0.0635 - accuracy: 0.9573 - val_loss: 0.2405 - val_accuracy: 0.8636
# Epoch 17/20
# 1563/1563 [==============================] - 86s 55ms/step - loss: 0.0615 - accuracy: 0.9595 - val_loss: 0.2468 - val_accuracy: 0.8625
# Epoch 18/20
# 1563/1563 [==============================] - 81s 52ms/step - loss: 0.0594 - accuracy: 0.9613 - val_loss: 0.2479 - val_accuracy: 0.8676
# Epoch 19/20
# 1563/1563 [==============================] - 79s 51ms/step - loss: 0.0578 - accuracy: 0.9629 - val_loss: 0.2625 - val_accuracy: 0.8618
# Epoch 20/20
# 1563/1563 [==============================] - 79s 51ms/step - loss: 0.0561 - accuracy: 0.9640 - val_loss: 0.2867 - val_accuracy: 0.8609

# %%
inputs = Input(shape=x_train.shape[1:])
x = LSTM(inputs)
y = Dense(5, activation="softmax")(x)
LSTM_model = Model(inputs = inputs, outputs = y)

# %%
opt = keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
LSTM_model.compile(loss='binary_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

# %%
LSTM_history = LSTM_model.fit(x_train_mlp, y_train,
              batch_size=64,
              epochs=20,
              validation_data=(x_test_mlp, y_test))
# Out:
# Epoch 1/20
# 1563/1563 [==============================] - 104s 66ms/step - loss: 0.3374 - accuracy: 0.5895 - val_loss: 0.1880 - val_accuracy: 0.8068
# Epoch 2/20
# 1563/1563 [==============================] - 112s 72ms/step - loss: 0.1738 - accuracy: 0.8285 - val_loss: 0.1766 - val_accuracy: 0.8283
# Epoch 3/20
# 1563/1563 [==============================] - 114s 73ms/step - loss: 0.1559 - accuracy: 0.8447 - val_loss: 0.1534 - val_accuracy: 0.8568
# Epoch 4/20
# 1563/1563 [==============================] - 112s 72ms/step - loss: 0.1363 - accuracy: 0.8658 - val_loss: 0.1467 - val_accuracy: 0.8577
# Epoch 5/20
# 1563/1563 [==============================] - 112s 72ms/step - loss: 0.1211 - accuracy: 0.8822 - val_loss: 0.1379 - val_accuracy: 0.8766
# Epoch 6/20
# 1563/1563 [==============================] - 110s 71ms/step - loss: 0.1100 - accuracy: 0.8935 - val_loss: 0.1166 - val_accuracy: 0.8967
# Epoch 7/20
# 1563/1563 [==============================] - 112s 72ms/step - loss: 0.1001 - accuracy: 0.9046 - val_loss: 0.1302 - val_accuracy: 0.8773
# Epoch 8/20
# 1563/1563 [==============================] - 112s 71ms/step - loss: 0.0937 - accuracy: 0.9098 - val_loss: 0.1412 - val_accuracy: 0.8615
# Epoch 9/20
# 1563/1563 [==============================] - 117s 75ms/step - loss: 0.0908 - accuracy: 0.9128 - val_loss: 0.1095 - val_accuracy: 0.9003
# Epoch 10/20
# 1563/1563 [==============================] - 112s 72ms/step - loss: 0.0831 - accuracy: 0.9195 - val_loss: 0.1140 - val_accuracy: 0.8971
# Epoch 11/20
# 1563/1563 [==============================] - 112s 72ms/step - loss: 0.0780 - accuracy: 0.9249 - val_loss: 0.1097 - val_accuracy: 0.9018
# Epoch 12/20
# 1563/1563 [==============================] - 109s 70ms/step - loss: 0.0769 - accuracy: 0.9252 - val_loss: 0.1081 - val_accuracy: 0.9050
# Epoch 13/20
# 1563/1563 [==============================] - 112s 72ms/step - loss: 0.0730 - accuracy: 0.9301 - val_loss: 0.1186 - val_accuracy: 0.9032
# Epoch 14/20
# 1563/1563 [==============================] - 112s 71ms/step - loss: 0.0721 - accuracy: 0.9299 - val_loss: 0.1119 - val_accuracy: 0.9006
# Epoch 15/20
# 1563/1563 [==============================] - 112s 71ms/step - loss: 0.0780 - accuracy: 0.9241 - val_loss: 0.1204 - val_accuracy: 0.9056
# Epoch 16/20
# 1563/1563 [==============================] - 116s 74ms/step - loss: 0.0635 - accuracy: 0.9384 - val_loss: 0.1112 - val_accuracy: 0.9124
# Epoch 17/20
# 1563/1563 [==============================] - 117s 75ms/step - loss: 0.0619 - accuracy: 0.9410 - val_loss: 0.1043 - val_accuracy: 0.9147
# Epoch 18/20
# 1563/1563 [==============================] - 116s 74ms/step - loss: 0.0562 - accuracy: 0.9478 - val_loss: 0.1145 - val_accuracy: 0.9181
# Epoch 19/20
# 1563/1563 [==============================] - 116s 74ms/step - loss: 0.0563 - accuracy: 0.9470 - val_loss: 0.1191 - val_accuracy: 0.9136
# Epoch 20/20
# 1563/1563 [==============================] - 112s 72ms/step - loss: 0.0578 - accuracy: 0.9464 - val_loss: 0.1144 - val_accuracy: 0.9213

# %%
CNN_model.save("CNN_REP_MITBIH")
LSTM_model.save("LSTM_REP_MITBIH")
MLP_model.save("MLP_REP_MITBIH")
# Out:
# INFO:tensorflow:Assets written to: CNN_REP_MITBIH\assets
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses, lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses, lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: LSTM_REP_MITBIH\assets
# INFO:tensorflow:Assets written to: LSTM_REP_MITBIH\assets
# INFO:tensorflow:Assets written to: MLP_REP_MITBIH\assets
# INFO:tensorflow:Assets written to: MLP_REP_MITBIH\assets

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sn
def plot_history(history):
    fig1, ax_acc = plt.subplots()
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.title('Model Accuracy')
    plt.legend(['Training', 'Validation'], loc='lower right')
    plt.show()
    fig2, ax_loss = plt.subplots()
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Model Loss')
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.legend(['Training', 'Validation'], loc='upper right')
    plt.show()
    
def plot_confusion(model, name):
    predictions = model.predict(x_test)
    matrix = confusion_matrix(y_test.argmax(axis=1), predictions.argmax(axis=1))
    df_cm = pd.DataFrame(matrix, range(5), range(5))
    plt.figure(figsize=(10,7))
    sn.set(font_scale=1.4) 
    labels = ["Normal", "Supraventricular Ectopic", "Ventricular Ectopic", "Fusion", "Unknown"]
    sn.heatmap(df_cm, annot=True, annot_kws={"size": 10}, xticklabels=labels, yticklabels=labels)
    plt.xlabel("Actual")
    plt.ylabel("Predicted")
    plt.title(name)
    plt.show()

# %%
plot_history(CNN_history)
plot_confusion(CNN_model, "MIT CNN Transfered")

# %%
plot_history(LSTM_history)
plot_confusion(LSTM_model, "MIT LSTM Transfered")

# %%
plot_history(MLP_history)
plot_confusion(MLP_model, "MIT MLP Transfered")
