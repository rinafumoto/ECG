# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dropout, Dense, Conv1D, MaxPooling1D, Flatten, LeakyReLU, Input, Average
from tensorflow import keras
import tensorflow as tf
import pickle
import matplotlib.pyplot as plt
from sklearn import metrics
import numpy as np
import pandas as pd

# %%
TRAIN_SET = '../mit_train_set.pickle'
TEST_SET = '../mit_test_set.pickle'

with open(TEST_SET, 'rb') as file:
    test_set = pickle.load(file)
    x_test = test_set['x']
    y_test = test_set['y']

with open(TRAIN_SET, 'rb') as file:
    train_set = pickle.load(file)
    x_train = train_set['x']
    y_train = train_set['y']
    
x_train_mlp = x_train
x_test_mlp = x_test

x_train = tf.expand_dims(x_train, axis=2)
x_test = tf.expand_dims(x_test, axis=2)

# %%
num_classes = 5
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %%
CNN_model  = keras.models.load_model('CNN_REP_MITBIH')
LSTM_model = keras.models.load_model('LSTM_REP_MITBIH')
MLP_model  = keras.models.load_model('MLP_REP_MITBIH')

# %%
inputs = Input(shape=x_train.shape[1:])
cnn = CNN_model(inputs)
lstm = LSTM_model(inputs)
mlp = MLP_model(inputs)

y = Average()([cnn, lstm, mlp])


model = Model(inputs = inputs, outputs = y)

# %%
opt = keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
model.compile(loss='binary_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

# %%
history = model.fit(x_train_mlp, y_train,
              batch_size=64,
              epochs=20,
              validation_data=(x_test_mlp, y_test))
# Out:
# Epoch 1/20
# 1563/1563 [==============================] - 168s 106ms/step - loss: 0.0256 - accuracy: 0.9841 - val_loss: 0.1159 - val_accuracy: 0.9279
# Epoch 2/20
# 1563/1563 [==============================] - 161s 103ms/step - loss: 0.0293 - accuracy: 0.9824 - val_loss: 0.1323 - val_accuracy: 0.9206
# Epoch 3/20
# 1563/1563 [==============================] - 182s 117ms/step - loss: 0.0261 - accuracy: 0.9842 - val_loss: 0.1320 - val_accuracy: 0.9206
# Epoch 4/20
# 1563/1563 [==============================] - 173s 110ms/step - loss: 0.0260 - accuracy: 0.9844 - val_loss: 0.1345 - val_accuracy: 0.9260
# Epoch 5/20
# 1563/1563 [==============================] - 175s 112ms/step - loss: 0.0253 - accuracy: 0.9848 - val_loss: 0.1222 - val_accuracy: 0.9174
# Epoch 6/20
# 1563/1563 [==============================] - 172s 110ms/step - loss: 0.0266 - accuracy: 0.9837 - val_loss: 0.1416 - val_accuracy: 0.9181
# Epoch 7/20
# 1563/1563 [==============================] - 171s 109ms/step - loss: 0.0261 - accuracy: 0.9839 - val_loss: 0.1386 - val_accuracy: 0.9227
# Epoch 8/20
# 1563/1563 [==============================] - 188s 120ms/step - loss: 0.0241 - accuracy: 0.9860 - val_loss: 0.1325 - val_accuracy: 0.9222
# Epoch 9/20
# 1563/1563 [==============================] - 172s 110ms/step - loss: 0.0252 - accuracy: 0.9851 - val_loss: 0.1636 - val_accuracy: 0.9084
# Epoch 10/20
# 1563/1563 [==============================] - 159s 101ms/step - loss: 0.0288 - accuracy: 0.9829 - val_loss: 0.1284 - val_accuracy: 0.9213
# Epoch 11/20
# 1563/1563 [==============================] - 163s 104ms/step - loss: 0.0258 - accuracy: 0.9850 - val_loss: 0.1560 - val_accuracy: 0.9213
# Epoch 12/20
# 1563/1563 [==============================] - 158s 101ms/step - loss: 0.0224 - accuracy: 0.9871 - val_loss: 0.1512 - val_accuracy: 0.9239
# Epoch 13/20
# 1563/1563 [==============================] - 157s 101ms/step - loss: 0.0215 - accuracy: 0.9876 - val_loss: 0.1415 - val_accuracy: 0.9234
# Epoch 14/20
# 1563/1563 [==============================] - 157s 101ms/step - loss: 0.0246 - accuracy: 0.9866 - val_loss: 0.1519 - val_accuracy: 0.9200
# Epoch 15/20
# 1563/1563 [==============================] - 157s 100ms/step - loss: 0.0236 - accuracy: 0.9862 - val_loss: 0.1406 - val_accuracy: 0.9306
# Epoch 16/20
# 1563/1563 [==============================] - 157s 100ms/step - loss: 0.0224 - accuracy: 0.9873 - val_loss: 0.1417 - val_accuracy: 0.9258
# Epoch 17/20
# 1563/1563 [==============================] - 157s 100ms/step - loss: 0.0234 - accuracy: 0.9860 - val_loss: 0.1336 - val_accuracy: 0.9244
# Epoch 18/20
# 1563/1563 [==============================] - 166s 106ms/step - loss: 0.0255 - accuracy: 0.9859 - val_loss: 0.1411 - val_accuracy: 0.9239
# Epoch 19/20
# 1563/1563 [==============================] - 173s 110ms/step - loss: 0.0210 - accuracy: 0.9884 - val_loss: 0.1548 - val_accuracy: 0.9234
# Epoch 20/20
# 1563/1563 [==============================] - 177s 113ms/step - loss: 0.0251 - accuracy: 0.9857 - val_loss: 0.1354 - val_accuracy: 0.9245

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sn
def plot_history(history):
    fig1, ax_acc = plt.subplots()
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.title('Model Accuracy')
    plt.legend(['Training', 'Validation'], loc='lower right')
    plt.show()
    fig2, ax_loss = plt.subplots()
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Model Loss')
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.legend(['Training', 'Validation'], loc='upper right')
    plt.show()
    
def plot_confusion(model, name):
    predictions = model.predict(x_test)
    matrix = confusion_matrix(y_test.argmax(axis=1), predictions.argmax(axis=1))
    df_cm = pd.DataFrame(matrix, range(5), range(5))
    plt.figure(figsize=(10,7))
    sn.set(font_scale=1.4) 
    labels = ["Normal", "Supraventricular Ectopic", "Ventricular Ectopic", "Fusion", "Unknown"]
    sn.heatmap(df_cm, annot=True, annot_kws={"size": 10}, xticklabels=labels, yticklabels=labels)
    plt.xlabel("Actual")
    plt.ylabel("Predicted")
    plt.title(name)
    plt.show()

# %%
plot_history(history)
plot_confusion(model, "MIT Transfered Ensemble")
